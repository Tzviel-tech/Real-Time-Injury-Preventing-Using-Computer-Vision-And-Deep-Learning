# %%
# !pip install streamlit
# !pip install streamlit_webrtc
# !pip install keras==2.9.0
# !pip install notebook==6.4.11
# !pip install numpy==1.23.0
# !pip install Markdown==3.3.7
# !pip install ipykernel==6.9.1
# !pip install ipython==8.3.0
# !pip install mediapipe==0.8.10
# !pip install pillow==9.1.1
# !pip install opencv-python==4.6.0.66
# !pip install opencv-contrib-python==4.6.0.66
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (1.36.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (9.1.1)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: jinja2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (4.22.0)
# Requirement already satisfied: toolz in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.15.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit_webrtc in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (0.47.7)
# Requirement already satisfied: aiortc<2.0.0,>=1.4.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit_webrtc) (1.9.0)
# Requirement already satisfied: packaging>=20.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit_webrtc) (24.1)
# Requirement already satisfied: streamlit>=0.84.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit_webrtc) (1.36.0)
# Requirement already satisfied: aioice<1.0.0,>=0.9.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (0.9.0)
# Requirement already satisfied: av<13.0.0,>=9.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (12.2.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (1.16.0)
# Requirement already satisfied: cryptography>=42.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (42.0.8)
# Requirement already satisfied: google-crc32c>=1.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (1.5.0)
# Requirement already satisfied: pyee>=9.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (11.1.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (0.10.0)
# Requirement already satisfied: pyopenssl>=24.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (24.1.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (1.26.4)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (9.1.1)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from streamlit>=0.84.1->streamlit_webrtc) (6.4.1)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aioice<1.0.0,>=0.9.0->aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (2.6.1)
# Requirement already satisfied: ifaddr>=0.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from aioice<1.0.0,>=0.9.0->aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (0.2.0)
# Requirement already satisfied: jinja2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (4.22.0)
# Requirement already satisfied: toolz in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (0.12.1)
# Requirement already satisfied: pycparser in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.0->aiortc<2.0.0,>=1.4.0->streamlit_webrtc) (2.22)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit_webrtc) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit>=0.84.1->streamlit_webrtc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit>=0.84.1->streamlit_webrtc) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.3.0->streamlit>=0.84.1->streamlit_webrtc) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit_webrtc) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit_webrtc) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit_webrtc) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.27->streamlit>=0.84.1->streamlit_webrtc) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit>=0.84.1->streamlit_webrtc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from rich<14,>=10.14.0->streamlit>=0.84.1->streamlit_webrtc) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.84.1->streamlit_webrtc) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.84.1->streamlit_webrtc) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=0.84.1->streamlit_webrtc) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit>=0.84.1->streamlit_webrtc) (1.15.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting keras==2.9.0
#   Using cached keras-2.9.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.16.2 requires keras>=3.0.0, but you have keras 2.9.0 which is incompatible.
# Successfully installed keras-2.9.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: notebook==6.4.11 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (6.4.11)
# Requirement already satisfied: jinja2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (3.1.4)
# Requirement already satisfied: tornado>=6.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (6.4.1)
# Requirement already satisfied: pyzmq>=17 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (26.0.3)
# Requirement already satisfied: argon2-cffi in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (5.14.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (5.7.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (7.4.9)
# Requirement already satisfied: ipython-genutils in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (0.2.0)
# Requirement already satisfied: nbformat in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (7.16.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (1.6.0)
# Requirement already satisfied: ipykernel in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (6.9.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (0.18.1)
# Requirement already satisfied: prometheus-client in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from notebook==6.4.11) (0.20.0)
# Requirement already satisfied: entrypoints in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=5.3.4->notebook==6.4.11) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-client>=5.3.4->notebook==6.4.11) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-core>=4.6.1->notebook==6.4.11) (4.2.2)
# Requirement already satisfied: beautifulsoup4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (6.1.0)
# Requirement already satisfied: defusedxml in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (8.0.0)
# Requirement already satisfied: jupyterlab-pygments in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (0.10.0)
# Requirement already satisfied: packaging in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (24.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (2.18.0)
# Requirement already satisfied: tinycss2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbconvert>=5->notebook==6.4.11) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbformat->notebook==6.4.11) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from nbformat->notebook==6.4.11) (4.22.0)
# Requirement already satisfied: ptyprocess in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from terminado>=0.8.3->notebook==6.4.11) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from argon2-cffi->notebook==6.4.11) (21.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel->notebook==6.4.11) (1.8.2)
# Requirement already satisfied: ipython>=7.23.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel->notebook==6.4.11) (8.3.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel->notebook==6.4.11) (0.1.7)
# Requirement already satisfied: appnope in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel->notebook==6.4.11) (0.1.4)
# Requirement already satisfied: six>=1.9.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook==6.4.11) (1.15.0)
# Requirement already satisfied: webencodings in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook==6.4.11) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6->nbconvert>=5->notebook==6.4.11) (3.19.2)
# Requirement already satisfied: backcall in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (0.2.0)
# Requirement already satisfied: decorator in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (0.19.1)
# Requirement already satisfied: pickleshare in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (3.0.47)
# Requirement already satisfied: setuptools>=18.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (58.0.4)
# Requirement already satisfied: stack-data in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.4.11) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat->notebook==6.4.11) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat->notebook==6.4.11) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat->notebook==6.4.11) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat->notebook==6.4.11) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook==6.4.11) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->nbconvert>=5->notebook==6.4.11) (2.5)
# Requirement already satisfied: pycparser in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook==6.4.11) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook==6.4.11) (0.8.4)
# Requirement already satisfied: wcwidth in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook==6.4.11) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.4.11) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.4.11) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.4.11) (0.2.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==1.23.0
#   Using cached numpy-1.23.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (2.2 kB)
# Using cached numpy-1.23.0-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.16.2 requires keras>=3.0.0, but you have keras 2.9.0 which is incompatible.
# tensorflow 2.16.2 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 1.23.0 which is incompatible.
# Successfully installed numpy-1.23.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Markdown==3.3.7 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (3.3.7)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from Markdown==3.3.7) (8.0.0)
# Requirement already satisfied: zipp>=0.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->Markdown==3.3.7) (3.19.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipykernel==6.9.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (6.9.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (1.8.2)
# Requirement already satisfied: ipython>=7.23.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (8.3.0)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (5.14.3)
# Requirement already satisfied: jupyter-client<8.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (7.4.9)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (6.4.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (1.6.0)
# Requirement already satisfied: appnope in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipykernel==6.9.1) (0.1.4)
# Requirement already satisfied: backcall in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (0.2.0)
# Requirement already satisfied: decorator in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (0.19.1)
# Requirement already satisfied: pickleshare in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (2.18.0)
# Requirement already satisfied: setuptools>=18.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (58.0.4)
# Requirement already satisfied: stack-data in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython>=7.23.1->ipykernel==6.9.1) (4.9.0)
# Requirement already satisfied: entrypoints in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-client<8.0->ipykernel==6.9.1) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-client<8.0->ipykernel==6.9.1) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-client<8.0->ipykernel==6.9.1) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-client<8.0->ipykernel==6.9.1) (26.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.9.1) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jupyter-core>=4.9.2->jupyter-client<8.0->ipykernel==6.9.1) (4.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.9.1) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel==6.9.1) (0.2.13)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client<8.0->ipykernel==6.9.1) (1.15.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.9.1) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.9.1) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel==6.9.1) (0.2.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipython==8.3.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (8.3.0)
# Requirement already satisfied: backcall in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (0.2.0)
# Requirement already satisfied: decorator in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (0.1.7)
# Requirement already satisfied: pickleshare in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (2.18.0)
# Requirement already satisfied: setuptools>=18.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from ipython==8.3.0) (58.0.4)
# Requirement already satisfied: stack-data in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (4.9.0)
# Requirement already satisfied: appnope in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from ipython==8.3.0) (0.1.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython==8.3.0) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython==8.3.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==8.3.0) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython==8.3.0) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython==8.3.0) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython==8.3.0) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from asttokens>=2.1.0->stack-data->ipython==8.3.0) (1.15.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement mediapipe==0.8.10 (from versions: 0.9.1.0, 0.9.2.1, 0.9.3.0, 0.10.0, 0.10.1, 0.10.2, 0.10.3, 0.10.5, 0.10.7, 0.10.8, 0.10.9, 0.10.10, 0.10.11, 0.10.13, 0.10.14)
# ERROR: No matching distribution found for mediapipe==0.8.10
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow==9.1.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (9.1.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python==4.6.0.66 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from opencv-python==4.6.0.66) (1.23.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-contrib-python==4.6.0.66 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from opencv-contrib-python==4.6.0.66) (1.23.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.16.2)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x10266cb80>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/keras/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x102638190>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/keras/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x10266a9a0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/keras/
# Collecting keras>=3.0.0 (from tensorflow)
#   Using cached keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.37.1)
# Collecting numpy<2.0.0,>=1.23.5 (from tensorflow)
#   Using cached numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: rich in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from keras>=3.0.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (8.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.0.0->tensorflow) (2.18.0)
# Requirement already satisfied: zipp>=0.5 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/tzviels/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Using cached keras-3.4.1-py3-none-any.whl (1.1 MB)
# Using cached numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Installing collected packages: numpy, keras
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
# Successfully installed keras-3.4.1 numpy-1.26.4
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import tensorflow as tf
import math
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score, classification_report
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (LSTM, Dense, Concatenate, Attention, Dropout, Softmax,
                                     Input, Flatten, Activation, Bidirectional, Permute, multiply, 
                                     ConvLSTM2D, MaxPooling3D, TimeDistributed, Conv2D, MaxPooling2D)
from scipy import stats

# disable some of the tf/keras training warnings 
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "3"
tf.get_logger().setLevel("ERROR")
tf.autograph.set_verbosity(1)

# suppress untraced functions warning
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)
# Out:
# 2024-07-14 12:28:56.690149: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/tzviels/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # 1. Keypoints using MP Pose

# %%
# Pre-trained pose estimation model from Google Mediapipe
mp_pose = mp.solutions.pose

# Supported Mediapipe visualization tools
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    """
    This function detects human pose estimation keypoints from webcam footage
    
    """
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    """
    This function draws keypoints and landmarks detected by the human pose estimation model
    
    """
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )

# %%
cap = cv2.VideoCapture(0) # camera object
HEIGHT = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # webcam video frame height
WIDTH = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # webcam video frame width
FPS = int(cap.get(cv2.CAP_PROP_FPS)) # webcam video fram rate 

# Set and test mediapipe model using webcam
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()
      
        # Make detection
        image, results = mediapipe_detection(frame, pose)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
        except:
            pass
        
        # Render detections
        draw_landmarks(image, results)               
        
        # Display frame on screen
        cv2.imshow('OpenCV Feed', image)
        
        # Exit / break out logic
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1720949484.173736   16690 gl_context.cc:357] GL version: 2.1 (2.1 ATI-5.5.17), renderer: AMD Radeon Pro 5500M OpenGL Engine
# W0000 00:00:1720949484.319755 2038158 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720949484.330588 2038167 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 7>()
#       7 with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#       8     while cap.isOpened():
#       9
#      10         # Read feed
# ---> 11         ret, frame = cap.read()
#      13         # Make detection
#      14         image, results = mediapipe_detection(frame, pose)
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Extract Keypoints

# %%
# Recollect and organize keypoints from the test
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
# 33 landmarks with 4 values (x, y, z, visibility)
num_landmarks = len(landmarks)
num_values = len(test)
num_input_values = num_landmarks*num_values

# %%
# This is an example of what we would use as an input into our AI models
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)

# %%
def extract_keypoints(results):
    """
    Processes and organizes the keypoints detected from the pose estimation model 
    to be used as inputs for the exercise decoder models
    
    """
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    return pose

# %% [markdown]
# # 3. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays

# Ensure the directory exists
os.makedirs(os.path.dirname(DATA_PATH), exist_ok=True)
DATA_PATH = os.path.join(os. getcwd(),'data') 
print(DATA_PATH)

# make directory if it does not exist yet
if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

# Actions/exercises that we try to detect
actions = np.array(['curl', 'press', 'squat'])
num_classes = len(actions)

# How many videos worth of data
no_sequences = 50

# Videos are going to be this many frames in length
sequence_length = FPS*1

# Folder start
# Change this to collect more data and not lose previously collected data
start_folder = 101
# Out:
# /Users/tzviels/Final-Project/Final-Project/data

# %%
# Build folder paths
for action in actions:     
    for sequence in range(start_folder,no_sequences+start_folder):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))  
        except:
            pass

# %% [markdown]
# # 4. Collect Keypoint Values for Training and Testing

# %%
# Colors associated with each exercise (e.g., curls are denoted by blue, squats are denoted by orange, etc.)
colors = [(245,117,16), (117,245,16), (16,117,245)]

# %%
# Collect Training Data

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    # Loop through actions
    for idx, action in enumerate(actions):
        # Loop through sequences (i.e., videos)
        for sequence in range(start_folder, start_folder+no_sequences):
            # Loop through video length (i.e, sequence length)
            for frame_num in range(sequence_length):
                # Read feed
                ret, frame = cap.read()
                
                # Make detection
                image, results = mediapipe_detection(frame, pose)

                # Extract landmarks
                try:
                    landmarks = results.pose_landmarks.landmark
                except:
                    pass
                
                # Render detections
                draw_landmarks(image, results) 

                # Apply visualization logic
                if frame_num == 0: # If first frame in sequence, print that you're starting a new data collection and wait 500 ms
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)
                    
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else: 
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 8, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting {} Video # {}'.format(action, sequence), (15,30), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, colors[idx], 4, cv2.LINE_AA)
                    
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)

                # Export keypoints (sequence + pose landmarks)
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1720949542.438444   16690 gl_context.cc:357] GL version: 2.1 (2.1 ATI-5.5.17), renderer: AMD Radeon Pro 5500M OpenGL Engine
# W0000 00:00:1720949542.577850 2038875 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720949542.593455 2038876 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 5. Preprocess Data and Create Labels/Features

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
# Load and organize recorded training data
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):         
            # LSTM input data
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)  
            
        sequences.append(window)
        labels.append(label_map[action])

# %%
# Make sure first dimensions of arrays match
X = np.array(sequences)
y = to_categorical(labels).astype(int)
print(X.shape, y.shape)
# Out:
# (150, 1, 132) (150, 3)

# %%
# Split into training, validation, and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)
print(X_train.shape, y_train.shape)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=15/90, random_state=2)
# Out:
# (135, 1, 132) (135, 3)

# %% [markdown]
# # 6. Build and Train Neural Networks

# %%
# Callbacks to be used during neural network training 
es_callback = EarlyStopping(monitor='val_loss', min_delta=5e-4, patience=10, verbose=0, mode='min')
lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001, verbose=0, mode='min')
chkpt_callback = ModelCheckpoint(filepath=DATA_PATH, monitor='val_loss', verbose=0, save_best_only=True, 
                                 save_weights_only=False, mode='min', save_freq=1)

# Optimizer
opt = tf.keras.optimizers.Adam(learning_rate=0.01)

# some hyperparamters
batch_size = 32
max_epochs = 500
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 4>()
#       2 es_callback = EarlyStopping(monitor='val_loss', min_delta=5e-4, patience=10, verbose=0, mode='min')
#       3 lr_callback = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001, verbose=0, mode='min')
# ----> 4 chkpt_callback = ModelCheckpoint(filepath=DATA_PATH, monitor='val_loss', verbose=0, save_best_only=True,
#       5                                  save_weights_only=False, mode='min', save_freq=1)
#       7 # Optimizer
#       8 opt = tf.keras.optimizers.Adam(learning_rate=0.01)
#
# File ~/Library/Python/3.9/lib/python/site-packages/keras/src/callbacks/model_checkpoint.py:191, in ModelCheckpoint.__init__(self, filepath, monitor, verbose, save_best_only, save_weights_only, mode, save_freq, initial_value_threshold)
#     189 else:
#     190     if not self.filepath.endswith(".keras"):
# --> 191         raise ValueError(
#     192             "The filepath provided must end in `.keras` "
#     193             "(Keras model format). Received: "
#     194             f"filepath={self.filepath}"
#     195         )
#
# ValueError: The filepath provided must end in `.keras` (Keras model format). Received: filepath=/Users/tzviels/Final-Project/Final-Project/data

# %% [markdown]
# ## 6a. LSTM

# %%
# Set up Tensorboard logging and callbacks
NAME = f"ExerciseRecognition-LSTM-{int(time.time())}"
log_dir = os.path.join(os.getcwd(), 'logs', NAME,'')
tb_callback = TensorBoard(log_dir=log_dir)

callbacks = [tb_callback, es_callback, lr_callback, chkpt_callback]

# %%
lstm = Sequential()
lstm.add(LSTM(128, return_sequences=True, activation='relu', input_shape=(sequence_length, num_input_values)))
lstm.add(LSTM(256, return_sequences=True, activation='relu'))
lstm.add(LSTM(128, return_sequences=False, activation='relu'))
lstm.add(Dense(128, activation='relu'))
lstm.add(Dense(64, activation='relu'))
lstm.add(Dense(actions.shape[0], activation='softmax'))
print(lstm.summary())

# %%
lstm.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
lstm.fit(X_train, y_train, batch_size=batch_size, epochs=max_epochs, validation_data=(X_val, y_val), callbacks=callbacks)

# %% [markdown]
# ## 6b. LSTM + Attention

# %%
# Set up Tensorboard logging and callbacks
NAME = f"ExerciseRecognition-AttnLSTM-{int(time.time())}"
log_dir = os.path.join(os.getcwd(), 'logs', NAME,'')
tb_callback = TensorBoard(log_dir=log_dir)

callbacks = [tb_callback, es_callback, lr_callback, chkpt_callback]

# %%
def attention_block(inputs, time_steps):
    """
    Attention layer for deep neural network
    
    """
    # Attention weights
    a = Permute((2, 1))(inputs)
    a = Dense(time_steps, activation='softmax')(a)
    
    # Attention vector
    a_probs = Permute((2, 1), name='attention_vec')(a)
    
    # Luong's multiplicative score
    output_attention_mul = multiply([inputs, a_probs], name='attention_mul') 
    
    return output_attention_mul

# %%
HIDDEN_UNITS = 256

# Input
inputs = Input(shape=(sequence_length, num_input_values))

# Bi-LSTM
lstm_out = Bidirectional(LSTM(HIDDEN_UNITS, return_sequences=True))(inputs)

# Attention
attention_mul = attention_block(lstm_out, sequence_length)
attention_mul = Flatten()(attention_mul)

# Fully Connected Layer
x = Dense(2*HIDDEN_UNITS, activation='relu')(attention_mul)
x = Dropout(0.5)(x)

# Output
x = Dense(actions.shape[0], activation='softmax')(x)

# Bring it all together
AttnLSTM = Model(inputs=[inputs], outputs=x)
print(AttnLSTM.summary())

# %%
AttnLSTM.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
AttnLSTM.fit(X_train, y_train, batch_size=batch_size, epochs=max_epochs, validation_data=(X_val, y_val), callbacks=callbacks)

# %%
# Model map
models = {
    'LSTM': lstm, 
    'LSTM_Attention_128HUs': AttnLSTM, 
}

# %% [markdown]
# # 7a. Save Weights

# %%
for model_name, model in models.items():
    save_dir = os.path.join(os.getcwd(), f"{model_name}.h5")
    model.save(save_dir)

# %% [markdown]
# # 7b. Load Weights

# %%
# Run model rebuild before doing this
for model_name, model in models.items():
    load_dir = os.path.join(os.getcwd(), f"{model_name}.h5")
    model.load_weights(load_dir)

# %% [markdown]
# # 8. Make Predictions

# %%
for model in models.values():
    res = model.predict(X_test, verbose=0)

# %% [markdown]
# # 9. Evaluations using Confusion Matrix and Accuracy

# %%
eval_results = {}
eval_results['confusion matrix'] = None
eval_results['accuracy'] = None
eval_results['precision'] = None
eval_results['recall'] = None
eval_results['f1 score'] = None

confusion_matrices = {}
classification_accuracies = {}   
precisions = {}
recalls = {}
f1_scores = {}

# %% [markdown]
# ## 9a. Confusion Matrices

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Confusion matrix
    confusion_matrices[model_name] = multilabel_confusion_matrix(ytrue, yhat)
    print(f"{model_name} confusion matrix: {os.linesep}{confusion_matrices[model_name]}")

# Collect results 
eval_results['confusion matrix'] = confusion_matrices

# %% [markdown]
# ## 9b. Accuracy

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Model accuracy
    classification_accuracies[model_name] = accuracy_score(ytrue, yhat)    
    print(f"{model_name} classification accuracy = {round(classification_accuracies[model_name]*100,3)}%")

# Collect results 
eval_results['accuracy'] = classification_accuracies

# %% [markdown]
# ## 9c. Precision, Recall, and F1 Score

# %%
for model_name, model in models.items():
    yhat = model.predict(X_test, verbose=0)
    
    # Get list of classification predictions
    ytrue = np.argmax(y_test, axis=1).tolist()
    yhat = np.argmax(yhat, axis=1).tolist()
    
    # Precision, recall, and f1 score
    report = classification_report(ytrue, yhat, target_names=actions, output_dict=True)
    
    precisions[model_name] = report['weighted avg']['precision']
    recalls[model_name] = report['weighted avg']['recall']
    f1_scores[model_name] = report['weighted avg']['f1-score'] 
   
    print(f"{model_name} weighted average precision = {round(precisions[model_name],3)}")
    print(f"{model_name} weighted average recall = {round(recalls[model_name],3)}")
    print(f"{model_name} weighted average f1-score = {round(f1_scores[model_name],3)}\n")

# Collect results 
eval_results['precision'] = precisions
eval_results['recall'] = recalls
eval_results['f1 score'] = f1_scores

# %% [markdown]
# # 10. Choose Model to Test in Real Time

# %%
model = AttnLSTM
model_name = 'AttnLSTM'

# %% [markdown]
# # 11. Calculate Joint Angles & Count Reps

# %%
def calculate_angle(a,b,c):
    """
    Computes 3D joint angle inferred by 3 keypoints and their relative positions to one another
    
    """
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle

# %%
def get_coordinates(landmarks, mp_pose, side, joint):
    """
    Retrieves x and y coordinates of a particular keypoint from the pose estimation model
         
     Args:
         landmarks: processed keypoints from the pose estimation model
         mp_pose: Mediapipe pose estimation model
         side: 'left' or 'right'. Denotes the side of the body of the landmark of interest.
         joint: 'shoulder', 'elbow', 'wrist', 'hip', 'knee', or 'ankle'. Denotes which body joint is associated with the landmark of interest.
    
    """
    coord = getattr(mp_pose.PoseLandmark,side.upper()+"_"+joint.upper())
    x_coord_val = landmarks[coord.value].x
    y_coord_val = landmarks[coord.value].y
    return [x_coord_val, y_coord_val]

# %%
def viz_joint_angle(image, angle, joint):
    """
    Displays the joint angle value near the joint within the image frame
    
    """
    cv2.putText(image, str(int(angle)), 
                   tuple(np.multiply(joint, [640, 480]).astype(int)), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA
                        )
    return

# %%
def count_reps(image, current_action, landmarks, mp_pose):
    """
    Counts repetitions of each exercise. Global count and stage (i.e., state) variables are updated within this function.
    
    """

    global curl_counter, press_counter, squat_counter, curl_stage, press_stage, squat_stage
    
    if current_action == 'curl':
        # Get coords
        shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        elbow = get_coordinates(landmarks, mp_pose, 'left', 'elbow')
        wrist = get_coordinates(landmarks, mp_pose, 'left', 'wrist')
        
        # calculate elbow angle
        angle = calculate_angle(shoulder, elbow, wrist)
        
        # curl counter logic
        if angle < 30:
            curl_stage = "up" 
        if angle > 140 and curl_stage =='up':
            curl_stage="down"  
            curl_counter +=1
        press_stage = None
        squat_stage = None
            
        # Viz joint angle
        viz_joint_angle(image, angle, elbow)
        
    elif current_action == 'press':
        
        # Get coords
        shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        elbow = get_coordinates(landmarks, mp_pose, 'left', 'elbow')
        wrist = get_coordinates(landmarks, mp_pose, 'left', 'wrist')

        # Calculate elbow angle
        elbow_angle = calculate_angle(shoulder, elbow, wrist)
        
        # Compute distances between joints
        shoulder2elbow_dist = abs(math.dist(shoulder,elbow))
        shoulder2wrist_dist = abs(math.dist(shoulder,wrist))
        
        # Press counter logic
        if (elbow_angle > 130) and (shoulder2elbow_dist < shoulder2wrist_dist):
            press_stage = "up"
        if (elbow_angle < 50) and (shoulder2elbow_dist > shoulder2wrist_dist) and (press_stage =='up'):
            press_stage='down'
            press_counter += 1
        curl_stage = None
        squat_stage = None
            
        # Viz joint angle
        viz_joint_angle(image, elbow_angle, elbow)
        
    elif current_action == 'squat':
        # Get coords
        # left side
        left_shoulder = get_coordinates(landmarks, mp_pose, 'left', 'shoulder')
        left_hip = get_coordinates(landmarks, mp_pose, 'left', 'hip')
        left_knee = get_coordinates(landmarks, mp_pose, 'left', 'knee')
        left_ankle = get_coordinates(landmarks, mp_pose, 'left', 'ankle')
        # right side
        right_shoulder = get_coordinates(landmarks, mp_pose, 'right', 'shoulder')
        right_hip = get_coordinates(landmarks, mp_pose, 'right', 'hip')
        right_knee = get_coordinates(landmarks, mp_pose, 'right', 'knee')
        right_ankle = get_coordinates(landmarks, mp_pose, 'right', 'ankle')
        
        # Calculate knee angles
        left_knee_angle = calculate_angle(left_hip, left_knee, left_ankle)
        right_knee_angle = calculate_angle(right_hip, right_knee, right_ankle)
        
        # Calculate hip angles
        left_hip_angle = calculate_angle(left_shoulder, left_hip, left_knee)
        right_hip_angle = calculate_angle(right_shoulder, right_hip, right_knee)
        
        # Squat counter logic
        thr = 165
        if (left_knee_angle < thr) and (right_knee_angle < thr) and (left_hip_angle < thr) and (right_hip_angle < thr):
            squat_stage = "down"
        if (left_knee_angle > thr) and (right_knee_angle > thr) and (left_hip_angle > thr) and (right_hip_angle > thr) and (squat_stage =='down'):
            squat_stage='up'
            squat_counter += 1
        curl_stage = None
        press_stage = None
            
        # Viz joint angles
        viz_joint_angle(image, left_knee_angle, left_knee)
        viz_joint_angle(image, left_hip_angle, left_hip)
        
    else:
        pass

# %% [markdown]
# # 12. Test in Real Time

# %%
def prob_viz(res, actions, input_frame, colors):
    """
    This function displays the model prediction probability distribution over the set of exercise classes
    as a horizontal bar graph
    
    """
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):        
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
predictions = []
res = []
threshold = 0.5 # minimum confidence to classify as an action/exercise
current_action = ''

# Rep counter logic variables
curl_counter = 0
press_counter = 0
squat_counter = 0
curl_stage = None
press_stage = None
squat_stage = None

# Camera object
cap = cv2.VideoCapture(0)

# Video writer object that saves a video of the real time test
fourcc = cv2.VideoWriter_fourcc('M','J','P','G') # video compression format
HEIGHT = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)) # webcam video frame height
WIDTH = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)) # webcam video frame width
FPS = int(cap.get(cv2.CAP_PROP_FPS)) # webcam video fram rate 

video_name = os.path.join(os.getcwd(),f"{model_name}_real_time_test.avi")
out = cv2.VideoWriter(video_name, cv2.VideoWriter_fourcc(*"MJPG"), FPS, (WIDTH,HEIGHT))

# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detection
        image, results = mediapipe_detection(frame, pose)
        
        # Draw landmarks
        draw_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)        
        sequence.append(keypoints)      
        sequence = sequence[-sequence_length:]
              
        if len(sequence) == sequence_length:
            res = model.predict(np.expand_dims(sequence, axis=0), verbose=0)[0]           
            predictions.append(np.argmax(res))
            current_action = actions[np.argmax(res)]
            confidence = np.max(res)
            
        #3. Viz logic
            # Erase current action variable if no probability is above threshold
            if confidence < threshold:
                current_action = ''

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
            # Count reps
            try:
                landmarks = results.pose_landmarks.landmark
                count_reps(
                    image, current_action, landmarks, mp_pose)
            except:
                pass

            # Display graphical information
            cv2.rectangle(image, (0,0), (640, 40), colors[np.argmax(res)], -1)
            cv2.putText(image, 'curl ' + str(curl_counter), (3,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'press ' + str(press_counter), (240,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(image, 'squat ' + str(squat_counter), (490,30), 
                           cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
         
        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        
        # Write to video file
        if ret == True:
            out.write(image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
cap.release()
out.release()
cv2.destroyAllWindows()
